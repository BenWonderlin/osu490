# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from circleguard import Circleguard, ReplayPath
from circleguard import KeylessCircleguard, ReplayDir
from circleguard.judgment import JudgmentType
from slider import Library
from slider.beatmap import Circle, Slider, Spinner

plt.style.use("ggplot")
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)

# %%
INDEX_PATH = "data/index.csv"
BEATMAP_PATH = "data/beatmaps"
REPLAY_PATH = "data/replays/osr"
DB_PATH = "data/replays/osr/.circleguard.db"
SLIDER_PATH = "data/beatmaps"

# %% [markdown]
# ## Load Data

# %%
# index and beatmaps

index_df = pd.read_csv(INDEX_PATH, low_memory = False)
beatmap_library = Library(BEATMAP_PATH)

print(f"Num. replays in index: {len(index_df)}")
print(f"Num. of beatmaps in library: {len(beatmap_library.ids)}")
index_df.head()
# Out:
# Num. replays in index: 381570
# Num. of beatmaps in library: 55079
#    Unnamed: 0                        replayHash  \
# 0           0  857623324645f59599fc4e9c1c7e1130
# 1           1  b1675645282756f18e0c3f142f290d94
# 2           2  6170131dcd9ad32d4c0287422b256423
# 3           3  d3fc501dadc1fabd60f847432cc3de84
# 4           4  8e62a939e4c97fe22cbd90e90d338a53
#
#                         beatmapHash  \
# 0  db4cdde15984869de346686ceb6bc1a5
# 1  04129d1b26d6bf3f35cb00a04f4a8c88
# 2  8e3e4e77e6498a994bfa7505e735155d
# 3  27f9c5f8496bfdab8623e3be6cf73f25
# 4  1e8f966c7a8f992cb2f3f5bab7d55925
#
#                                              summary  \
# 0  [7.44 ⭐] My Angel Shori | Imperial Circus Dead...
# 1  [6.55 ⭐] AlexTheProtoTTV | katagiri - Buta Mus...
# 2  [6.37 ⭐] Asio_ | Qrispy Joybox feat. mao - Col...
# 3  [6.3 ⭐] sotarks fan123 | DragonForce - Valley ...
# 4  [6.34 ⭐] XxSzymenxx | DragonForce - Through th...
#
#                          date       playerName modsReadable  mods  \
# 0  2022-11-11T08:03:56.656728   My Angel Shori          NaN     0
# 1  2022-11-11T04:37:52.235160  AlexTheProtoTTV          NaN     0
# 2  2022-11-11T08:01:02.823288            Asio_         HDDT    72
# 3  2022-11-11T07:46:29.042768   sotarks fan123          NaN     0
# 4  2022-03-11T10:40:06.741672       XxSzymenxx          NaN     0
#
#    performance-IsFail  performance-Accuracy  performance-Score  \
# 0               False              0.954368           28363840
# 1               False              0.857687            2363246
# 2               False              0.916667             777289
# 3                True              0.948815           45264320
# 4                True              0.731128             486150
#
#    performance-300s  performance-100s  performance-50s  performance-Misses  \
# 0              1771                72                1                  37
# 1               991               174               10                  50
# 2               272                31                0                   5
# 3              1111                68                1                  15
# 4               254                85               30                  24
#
#    performance-Geki  performance-Katu  performance-MaxCombo  performance-IsFC  \
# 0               422                50                   950             False
# 1               274               103                   194             False
# 2                57                20                   136             False
# 3               182                42                  1485             False
# 4                29                19                    99             False
#
#                    beatmap-Artist                           beatmap-Title  \
# 0  Imperial Circus Dead Decadence  Hyakki Yakou -Pandemonic Night Parade-
# 1                        katagiri                              Buta Musou
# 2         Qrispy Joybox feat. mao                        Colorful Minutes
# 3                     DragonForce                    Valley of the Damned
# 4                     DragonForce             Through the Fire and Flames
#
#   beatmap-Version  beatmap-Id  beatmap-SetId  beatmap-BPMMin beatmap-BPMMax  \
# 0          Youkai   3638479.0      1776682.0             134            235
# 1          AR 9.8   3777132.0      1647421.0             210            210
# 2  Beautiful Time   2584022.0      1242911.0             152            152
# 3      Apocalypse    675734.0        67565.0              71            200
# 4            Myth   1001682.0       382400.0             170            200
#
#    beatmap-HP  beatmap-OD  beatmap-AR  beatmap-CS  beatmap-MaxCombo  \
# 0         5.0         9.2         9.7         4.5              2515
# 1         4.5         9.2         9.8         3.8              1660
# 2         5.2         8.5         9.0         3.8               438
# 3         6.0         8.5         9.2         4.0              3089
# 4         6.2         9.0         9.5         4.0              3220
#
#    beatmap-HitObjects  beatmap-Circles  beatmap-Sliders  beatmap-Spinners  \
# 0                1881             1438              442                 1
# 1                1225              832              392                 1
# 2                 308              189              118                 1
# 3                2148             1486              660                 2
# 4                2126             1534              587                 5
#
#    beatmapPlay-BPMMin  beatmapPlay-BPMMax  beatmapPlay-HP  beatmapPlay-OD  \
# 0               134.0               235.0             5.0        9.200000
# 1               210.0               210.0             4.5        9.200000
# 2               228.0               228.0             5.2       10.083333
# 3                71.0               200.0             6.0        8.500000
# 4               170.0               200.0             6.2        9.000000
#
#    beatmapPlay-AR  beatmapPlay-CS  \
# 0        9.700000             4.5
# 1        9.800000             3.8
# 2       10.333333             3.8
# 3        9.200000             4.0
# 4        9.500000             4.0
#
#                                         osrReplayUrl
# 0  https://dl.issou.best/ordr/replays/cfc43370ca0...
# 1  https://dl.issou.best/ordr/replays/e35f6f3e3b1...
# 2  https://dl.issou.best/ordr/replays/f214715d45d...
# 3  https://dl.issou.best/ordr/replays/cf3f6778f86...
# 4  https://dl.issou.best/ordr/replays/b90ed42a04b...

# %%
# replays

cg = KeylessCircleguard( 
    db_path = DB_PATH,
    slider_dir = SLIDER_PATH,
    cache = True
)
replay_dir = ReplayDir(REPLAY_PATH)

cg.load_info(replay_dir)
replay_dir.replays = replay_dir.replays[:2500] # only considering a subset of replays for now
cg.load(replay_dir)

print(f"Num Replays Loaded: {len(replay_dir.all_replays())}")
# Out:
# Num Replays Loaded: 2500

# %% [markdown]
# ## Parse Notes

# %%
def get_hitobject_embedding(prev_obj, curr_obj, next_obj):
    pass

def filter_out_spinners(objects):
    return [o for o in objects if type(o) in (Slider, Circle)]

def get_embeddings(replay):

    beatmap = beatmap_library.lookup_by_md5(replay.beatmap_hash)

    res = []
    hitobjects = filter_out_spinners( beatmap.hit_objects() )
    
    res.append(get_hitobject_embedding(None, hitobjects[0], hitobjects[1]))
    for i in range(1, len(hitobjects) - 1):
        res.append( get_hitobject_embedding(hitobjects[i-1], hitobjects[i], hitobjects[i+1] ))
    res.append(get_hitobject_embedding(hitobjects[-2], hitobjects[-1], None))

    return res

# %%
def sort_judgments(judgments):
    try:
        return sorted(judgments, key = lambda j: j.hitobject.t)
    except TypeError:
        return []
    
def encode_judgment(judgment):
     t = judgment.type
     if t not in (JudgmentType.Hit300, JudgmentType.Hit100, JudgmentType.Hit50, JudgmentType.Miss):
        print(t)
        raise Exception()
     return [
          1 if t == JudgmentType.Hit300 else 0, 
          1 if t == JudgmentType.Hit100 else 0,
          1 if t == JudgmentType.Hit50 else 0,
          1 if t == JudgmentType.Miss else 0
     ]

def get_judgments(replay):
    return [ encode_judgment(j) for j in sort_judgments( cg.judgments(replay) ) ]

# %%
def validate_replay(replay):


    # sequence length

    beatmap = beatmap_library.lookup_by_md5(replay.beatmap_hash)
    beatmap_objects = beatmap.hit_objects()
    total_num_objects = len(beatmap_objects)
    
    beatmap_objects = filter_out_spinners(beatmap_objects)
    num_spinners = total_num_objects - len(beatmap_objects)

    replay_judgments = sort_judgments( cg.judgments(replay) )

    if len(beatmap_objects) != len(replay_judgments):
        print(f"Length mismatch between beatmap objects {len(beatmap_objects)} and replay judgments {len(replay_judgments)} of replay at {replay.path}.")
        return -1

    replay_objects = [ j.hitobject for j in replay_judgments]

    if len(replay_objects) != len(beatmap_objects):
        print(f"Length mismatch between replay objects {len(replay_objects)} and beatmap objects {len(beatmap_objects)} of replay at {replay.path}.")
        return -2
    

    # hitcounts

    judgment_encodings = [encode_judgment(j) for j in replay_judgments]
    judgment_hitcounts = np.sum(judgment_encodings, axis = 0)
    replay_hitcounts = np.array([ replay.count_300, replay.count_100, replay.count_50, replay.count_miss])

    hitcount_err = replay_hitcounts - judgment_hitcounts

    if sum(hitcount_err) != num_spinners:
        print(f"Hitcount mismatch ({judgment_hitcounts} vs. {replay_hitcounts}, num_spinners = {num_spinners}) of replay at {replay.path}.")
        return -3
        

    # position & offset alignment

    EPSILON = 1e-06

    for idx, _ in enumerate(beatmap_objects):

        replay_obj = replay_objects[idx]
        beatmap_obj = beatmap_objects[idx]

        if abs( replay_obj.time - beatmap_obj.time.total_seconds() * 1000 ) >= EPSILON : 
            print(f"Offset mismatch ({1.0 * replay_obj.time} vs. {beatmap_obj.time.total_seconds() * 1000}) at index {idx} of replay at {replay.path}.")
            return -4

        if "HR" not in str(replay.mods) and "EZ" not in str(replay.mods): 

            if replay_obj.x - beatmap_obj.position.x >= EPSILON:
                print(f"Position mismatch (x={replay_obj.x} vs. x={beatmap_obj.position.x}) at index {idx} of replay at {replay.path}.")
                return -5
            
            if replay_obj.y - beatmap_obj.position.y >= EPSILON:
                print(f"Position mismatch (y={replay_obj.y} vs. y={beatmap_obj.position.y}) at index {idx} of replay at {replay.path}.")
                return -5
            
    return 1

# %%
res = []
for idx, replay in enumerate(replay_dir):
    res.append(validate_replay(replay))
# Out:
# Hitcount mismatch ([118  23   1 916] vs. [109  31   2   9], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\00000f8351988aea8881aee93ffa7bbd.osr.
# Hitcount mismatch ([1222  264   41  794] vs. [1189  312   46   61], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\0000cb47a2940ce372322c033e4fed90.osr.
# Hitcount mismatch ([ 421   66    6 2054] vs. [419  74   6  34], num_spinners = 7) of replay at w:\Documents\osu490\data\replays\osr\0003181675e2bbf8d84bf73b50ae936a.osr.
# Hitcount mismatch ([769  79   4 414] vs. [764  87   4  17], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\00067865d7cc165c359f01ada7318f9e.osr.
# Hitcount mismatch ([566   0   0 687] vs. [572   0   0   8], num_spinners = 7) of replay at w:\Documents\osu490\data\replays\osr
num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\00a3c97cab2030f7596a3c73325b4bd1.osr.
# Hitcount mismatch ([200  39   2  26] vs. [200  42   2  20], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\00a5365e8d023fd7db76830aac203515.osr.
# Hitcount mismatch ([641  23   0 190] vs. [640  24   0  23], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\00a5d538a0a3f8238264aca7e6e3a297.osr.
# Hitcount mismatch ([325  56   3  93] vs. [314  72   3  32], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\00a6aaf69ecbd917a031e846fb8c8769.osr.
# Hitcount mismatch ([363  66   4 310] vs. [358  71   4  16], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\00a88714317586cb4e3dec4c666d69de.osr.
# Hitcount mismatch ([ 28  22   4 252] vs. [24 27  4  5], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\00ab29a10b8aeaedbe65c14e593e2fd0.osr.
# Hitcount mismatch ([659  39   1 265] vs. [654  50   1  20], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\00ab9b20ef59dfb42f6568749c58c318.osr.
# Hitcount mismatch ([498  77  15 476] vs. [591 294  46 113], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\00abdb25820df8381d187f2227c440d8.osr.
# Hitcount mismatch ([915  17   0 140] vs. [912  27   0  40], num_spinners = 4) of replay at w:\Documents\osu490\data\replays\osr\00aca15730c0b737d5745105e3f3e4e5.osr.
# Hitcount mismatch ([815  42   0 550] vs. [811  58   1  77], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\00adf8e9bfa067fcbf75dd25882afa7c.osr.
# Hitcount mismatch ([451  36   4 288] vs. [450  45   4  29], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\00adfb87b2b77ca9e7fae4f0d417c0e6.osr.
# Hitcount mismatch ([1112  188    9  281] vs. [1085  218    9   56], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\00aee36aea4c4cd9b61f977f2660f1b4.osr.
# Hitcount mismatch ([145  34   1 159] vs. [140  42   1  15], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\00b0188779a62b793dca1a88ed8c0e0a.osr.
# Hitcount mismatch ([228  35   0  44] vs. [218  47   0  38], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\00b3d0c09b778505dfc74fe3ea05d328.osr.
# Hitcount mismatch ([551 100  14 725] vs. [552 105  15  31], num_spinners = 4) of replay at w:\Documents\osu490\data\replays\osr\00b580ba5dca71f67cc8192b593352a0.osr.
# Hitcount mismatch ([166  12   0 260] vs. [172  16   0  15], num_spinners = 8) of replay at w:\Documents\osu490\data\replays\osr\00b715f3a3f4ce365b54cd8fdb2bec2c.osr.
# Hitcount mismatch ([591  53   1 271] vs. [587  65   1  32], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\00b73cab0cf0d3bdc5268ab9513af2ff.osr.
# Hitcount mismatch ([557 130   5  52] vs. [524 195   9  17], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\00b73e503cf51a6e749fac09bab6bef1.osr.
# Hitcount mismatch ([1201  222    8  329] vs. [1182  261    8   90], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\00b8ce428feef9ede8eef0ff5d5bb9de.osr.
# Hitcount mismatch ([111  12   0 527] vs. [109  15   0  14], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\00b9517948acc55b62ce6c4a66077de4.osr.
# Hitcount mismatch ([248  11   0  68] vs. [246  15   0  10], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\00ba741cc6f035a650a6bc1069dd2931.osr.
# Hitcount mismatch ([676 154  24  37] vs. [676 156  24  24], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\00baa7b0296946e26e138efe8baefa31.osr.
# Hitcount mismatch ([440  61   8 505] vs. [434  72   8  44], num_spinners = 3) of replay at w:\Documents\osu490\data\replays\osr\00bcc12de71737e2b1a5fe7e405e15d9.osr.
# Hitcount mismatch ([438   8   0  33] vs. [438   8   0  25], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\00bcd958c4e2055b0b8c65449a43e53f.osr.
# Hitcount mismatch ([1269  746   63  181] vs. [1252  770   63  102], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\00be291a76226e6183036e05904f729e.osr.
# Hitcount mismatch ([1706   74    8   63] vs. [1693   94    8   43], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\
num_spinners = 3) of replay at w:\Documents\osu490\data\replays\osr\00fb74821d7d688a52bbbfb6df64dcdc.osr.
# Hitcount mismatch ([ 332  212   62 1130] vs. [304 253  67  63], num_spinners = 6) of replay at w:\Documents\osu490\data\replays\osr\00fc0b06ceb733770d61d7ca959b00c4.osr.
# Hitcount mismatch ([206   3   0 123] vs. [206   5   0   9], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\00fde93dcd00d4069fdfc2fa87afd18d.osr.
# Hitcount mismatch ([764 129  13 159] vs. [737 161  15  54], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\00fe311c8d8e406efb8c796cc3833b9e.osr.
# Hitcount mismatch ([ 71   5   4 244] vs. [72  8  4  8], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\00fe6bc588cc29618698a70894aa6672.osr.
# Hitcount mismatch ([280  68   4 125] vs. [272  81   4  58], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\0102a9453ca21893884da22dcd0b2572.osr.
# Hitcount mismatch ([135   8   0 608] vs. [132  14   0   7], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\01038e48c12d243fd243e8d5dca91cbb.osr.
# Hitcount mismatch ([291  48  13  54] vs. [286  75  13  31], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\010632e223e1f28cf5d3833e973b5a23.osr.
# Hitcount mismatch ([197  75  10 595] vs. [194  81  10  14], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\010865ff787d12830cba48925500e248.osr.
# Hitcount mismatch ([608   7   0 529] vs. [600  20   0  17], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\0108a9cea5763af000e675cf7e05ae39.osr.
# Hitcount mismatch ([300  36   3 937] vs. [296  50   3  24], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\0109d09132b358199e8759d88842e4c9.osr.
# Hitcount mismatch ([1155   29    5  292] vs. [1142   53    5   40], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\010a8a52df4ac85ad7c69d2e3de84ed0.osr.
# Hitcount mismatch ([1169  397   57  570] vs. [1058  537   72  168], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\010df33814315b0f3dfa82a03127aa53.osr.
# Hitcount mismatch ([342  27   2  20] vs. [339  31   2  18], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\010f311422f8a9285779a73cb701b4fb.osr.
# Hitcount mismatch ([121   8   3 113] vs. [120  11   3  15], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\011082575329512cf4a0f6e2a58f273d.osr.
# Hitcount mismatch ([325  25   0 135] vs. [299  51   2  19], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\011085f4bbb4381f421636503b281335.osr.
# Hitcount mismatch ([1027  339   53  916] vs. [1020  371   50   56], num_spinners = 10) of replay at w:\Documents\osu490\data\replays\osr\0110ced7513c1a48492a7b918f0b16c0.osr.
# Hitcount mismatch ([413   2   1 591] vs. [395  24   1   6], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\01112a6b8f9fa34c4dcf8516185ba9b3.osr.
# Hitcount mismatch ([201  31   4 205] vs. [194  45   5  25], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\0111cd2f616a20f6c4bdd70e83aaf022.osr.
# Hitcount mismatch ([951 239  43 285] vs. [979 281  44 146], num_spinners = 6) of replay at w:\Documents\osu490\data\replays\osr\0112f003fbf026dc4a5ab19505114ac5.osr.
# Hitcount mismatch ([1097  206   29  186] vs. [1001  328   33   74], num_spinners = 3) of replay at w:\Documents\osu490\data\replays\osr\0113f9bfbadfa287ec9c38441430f7cb.osr.
# Hitcount mismatch ([481  79  12 323] vs. [473 104  13  56], num_spinners = 3) of replay at w:\Documents\osu490\data\replays\osr\011b1d5344539db96a1532ff8ce782b2.osr.
# Hitcount mismatch ([638  44   1 203] vs. [630  67   1  47], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\011b7ff38bbe247c541d4ab9df4d3047.osr.
# Hitcount mismatch ([754 308  20 190] vs. [719 345  23  37], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\011c5f86b5d8ba61754e3770956a8ece.osr.
# Hitcount mismatch ([ 83   5   3 256] vs. [80  9  3 13], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\011cf1338b118eeb75a98dc050682984.osr.
# Hitcount mismatch ([1135  158    5   40] vs. [1135  159    5   19], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\011d86e2a80ce7c6ccb145579ab2a877.osr.
# Hitcount mismatch ([960 215  25 170] vs. [931 300  28  82], num_spinners = 7) of replay at w:\Documents\osu490\data\replays\osr
num_spinners = 3) of replay at w:\Documents\osu490\data\replays\osr\017b356a4409cb320524e84b2e2c5f21.osr.
# Hitcount mismatch ([871 134  22 479] vs. [846 154  24  32], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\017ccd5bbb2a9017068e5dd61aa5addb.osr.
# Hitcount mismatch ([549  24   1  30] vs. [498  87   1  17], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\017d622a1c28711e7680dd7653b5fa71.osr.
# Hitcount mismatch ([428  47   1 246] vs. [423  56   1  22], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\017d9c13944462c82332c13a9cb83b5d.osr.
# Hitcount mismatch ([228  15   0 259] vs. [226  17   0  11], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\017e3ad7233a721f71a37c2fe0bf1624.osr.
# Hitcount mismatch ([492   9  10 576] vs. [482  30  10  24], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\017ecba9d714245e875e6261b58f3b60.osr.
# Hitcount mismatch ([ 12   2   3 375] vs. [10  4  3 12], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\018060e2072a0649b79f64777bbbfcc2.osr.
# Hitcount mismatch ([96 16  1 48] vs. [94 17  2  4], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\018100bb390c6312da672a105b9be98b.osr.
# Hitcount mismatch ([379  21   1 445] vs. [376  24   1  25], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\0182091a925715619895dfba26739341.osr.
# Hitcount mismatch ([1091   99    1  175] vs. [1082  110    1   23], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\01828358a0add1970ac0131923b0019b.osr.
# Hitcount mismatch ([1292  126   37   97] vs. [1276  172   37   67], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\0183f4b85df059bbaad3e5c27a738db4.osr.
# Hitcount mismatch ([286  27   3  76] vs. [276  46   3  14], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\018477441eb7609fcc07800ddf883d52.osr.
# Hitcount mismatch ([276  33   1  65] vs. [269  43   1  23], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\01854c038e3d2d0be14472916c4ba113.osr.
# Hitcount mismatch ([450  52   0 331] vs. [427  77   0  18], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\018603691c584c32e4887e83d2cdaacc.osr.
# Hitcount mismatch ([746  33   1  72] vs. [745  35   1   8], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\018663ec04e896ea2b9be3e47401fa75.osr.
# Hitcount mismatch ([1195  138    6  187] vs. [1128  253    8   38], num_spinners = 6) of replay at w:\Documents\osu490\data\replays\osr\0187c42aca8c9f758b89dc2d1c188f64.osr.
# Hitcount mismatch ([ 69  20   2 223] vs. [69 23  2 14], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\01894322aeb407ecb0d09d7861cd6c45.osr.
# Hitcount mismatch ([ 510  161    8 1254] vs. [502 174   9  25], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\018a4dd037e2a9c9386ff8489cb6cea9.osr.
# Hitcount mismatch ([ 62   8   4 399] vs. [61 17  4 10], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\018ace5d55b86498b6a0516f7e2e5192.osr.
# Hitcount mismatch ([689  39   2  24] vs. [681  51   3  20], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\018ca8e271860d7090d1a7d73ee2964d.osr.
# Hitcount mismatch ([260   5   0  91] vs. [258   7   0  21], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\018cac8ac5cc35989a11e34a2f3f4c4f.osr.
# Hitcount mismatch ([292  53   4 737] vs. [289  61   4  34], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\018d9b40e9fecf7771abf9b3bd997d91.osr.
# Hitcount mismatch ([288 227  86 156] vs. [258 243  98  80], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\019055e84b61ea3431f903a43f3f3f6e.osr.
# Hitcount mismatch ([  55   34   13 1339] vs. [39 53 13 22], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\01929a7dec5844f08f139a117770a231.osr.
# Hitcount mismatch ([614 103   9 371] vs. [597 135   9 106], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\0193ef1ef4e092f4f575de8cb7aa1ebf.osr.
# Hitcount mismatch ([160   5   0  18] vs. [160   5   0  13], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\0194ff2c93a2109a710e7163b4042708.osr.
# Hitcount mismatch ([622 184  40 174] vs. [601 233  45  83], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\019805569a20e3e1c1092e950d9006ae.osr.
# Hitcount mismatch ([258   1   0  86] vs. [255   5   0   7], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\019abbb52038858cd616c90a635caa0b.osr.
# Hitcount mismatch ([148  17   0 241] vs. [147  27   0  10], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\019df891f6d6abb5fe25a125d2902836.osr.
# Hitcount mismatch ([700  36   0  54] vs. [696  45   0  16], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\01a156e8000591109e0da6f08a40f355.osr.
# Hitcount mismatch ([728  81  35 809] vs. [652 181  35  40], num_spinners = 0) of replay at w:\Documents\osu490\data\replays\osr\01a212405d62c9d5182c20a3b4f126c3.osr.
# Hitcount mismatch ([ 471   40    0 1066] vs. [467  45   0   9], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\01a27c1a5b743b1aaabc8dd8fa2593e8.osr.
# Hitcount mismatch ([399  73   8 121] vs. [379 100   8  61], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\01a2dd0e9f8be8d4cdfd90c646939c59.osr.
# Hitcount mismatch ([1744   61    6  321] vs. [1724   82    6   20], num_spinners = 1) of replay at w:\Documents\osu490\data\replays\osr\01a4c703be4a2d762b0997e126ab205c.osr.
# Hitcount mismatch ([482  35   4 263] vs. [463  57   4  17], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\01a57ee6c3f668ed4646276a98336913.osr.
# Hitcount mismatch ([551  24   2  58] vs. [542  44   2  26], num_spinners = 2) of replay at w:\Documents\osu490\data\replays\osr\01a59e527d23bd5f93d51b99eac584ab.osr.
# Hitcount mismatch ([653  64   1 313] vs. [646  73   1  19], num_spinners = 3) of replay at w:\Documents\osu490\data\replays\osr\01a6f0aad3b715bda8c02e34425bc677.osr.

# %%
res = np.array(res)
np.mean(res == 1)
# Out:
# 0.8616

# %%
mods = pd.Series([str(r.mods) for r in replay_dir])
mods.value_counts()
# Out:
# NM            1364
# HDDT           268
# HD             203
# DT             177
# HDHR            73
# NF              70
# HR              65
# HDNC            43
# NC              24
# HDNF            19
# HDDTHR          19
# EZ              16
# V2              11
# FL              10
# HDDTHRFL         9
# EZDT             9
# NFV2             7
# DTNF             7
# HRNF             6
# EZHD             6
# HDDTNF           6
# HT               5
# HRNFV2           5
# HDHRSD           4
# SO               4
# NCHR             4
# HDHRFL           4
# HDNFV2           3
# SD               3
# DTHR             3
# EZHDDT           3
# HDHRNF           3
# HDNCHRFL         3
# DTHRFL           2
# HDNCHRFLPF       2
# DTNFV2           2
# EZNFV2           2
# HTHR             2
# HRV2             2
# HDDTSD           2
# NCNF             2
# HDDTHRSD         2
# EZHDFL           2
# HDNCNF           2
# EZHT             2
# HDSD             2
# HDNCHRSD         1
# HDNCSO           1
# DTHRNF           1
# EZNC             1
# HDDTPF           1
# EZFL             1
# HDHTHR           1
# HDNCHRFLSD       1
# NCHRFL           1
# PF               1
# EZHTFL           1
# HDFL             1
# HRSO             1
# HDDTSO           1
# DTHRSD           1
# HDV2             1
# NCNFSO           1
# HDDTHRFLSD       1
# Name: count, dtype: int64

# %%
# import json
# with open("embeddings.json", "w") as f:
#     json.dump(embeddings, f)

# with open("judgments.json", "w") as f:
#     json.dump(judgments, f)
